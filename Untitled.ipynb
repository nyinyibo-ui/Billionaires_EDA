# %%
import pandas as pd
import panel as pn
import hvplot.pandas
import numpy as np
import matplotlib.pyplot as plt
import holoviews as hv
import plotly.express as px
import squarify
pn.extension('plotly')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="fe5e6e24-ab18-4e3f-893d-d381831e3f43" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e0793905-e013-48b8-8b46-2c112da8e893":{"version":"3.3.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"4c372f8e45ac4d58ba0f4066b08defa0","client_comm_id":"7d5698d70fee49bab599748251b61598"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{ ...
#   var render_items = [{"docid":"e0793905-e013-48b8-8b46-2c112da8e893","roots":{"p1002":"fe5e6e24-ab18-4e3f-893d-d381831e3f43"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
df=pd.read_csv("Processed_data.csv")
df.sample(10)
# Out:
#       rank  finalWorth                  personName  age         country  \
# 1320  1312        2300                   K. Dinesh   69           India
# 1688  1647        1800              Mofatraj Munot   79           India
# 355    352        6800               Milane Frantz   54   United States
# 228    223        8800     Carrie Perrodo & family   72  United Kingdom
# 1674  1647        1800          Valentin Kipyatkov   47          Cyprus
# 553    552        4900       Dagmar Dolby & family   82   United States
# 2164  2133        1300               Keiko Erikawa   74           Japan
# 107    108       15800  Karl Albrecht Jr. & family   58         Germany
# 1239  1217        2500            J. Tomilson Hill   75   United States
# 2625  2540        1000      Wang Jianfeng & family   58           China
#
#      countryOfCitizenship              source             industries  \
# 1320                India   Software services             Technology
# 1688                India         Real estate            Real Estate
# 355         United States           Pipelines                 Energy
# 228                France                 Oil                 Energy
# 1674               Cyprus            Software             Technology
# 553         United States  Dolby Laboratories             Technology
# 2164                Japan         Video games  Media & Entertainment
# 107               Germany        Supermarkets       Fashion & Retail
# 1239        United States         Investments  Finance & Investments
# 2625                China          Auto parts             Automotive
#
#      organization  selfMade  ...           title cpi_country  \
# 1320      Unknown      True  ...         Unknown      180.44
# 1688      Unknown      True  ...         Unknown      180.44
# 355       Unknown     False  ...         Unknown      117.24
# 228       Unknown     False  ...  Philanthropist      119.62
# 1674      Unknown      True  ...         Unknown      102.51
# 553       Unknown     False  ...         Unknown      117.24
# 2164      Unknown      True  ...         Unknown      105.48
# 107       Unknown     False  ...         Unknown      112.85
# 1239      Unknown      True  ...         Unknown      117.24
# 2625      Unknown      True  ...         Unknown      125.08
#
#      cpi_change_country           gdp_country  \
# 1320                7.7   $2,611,000,000,000
# 1688                7.7   $2,611,000,000,000
# 355                 7.5  $21,427,700,000,000
# 228                 1.7   $2,827,113,184,696
# 1674                0.3      $24,564,647,935
# 553                 7.5  $21,427,700,000,000
# 2164                0.5   $5,081,769,542,380
# 107                 1.4   $3,845,630,030,824
# 1239                7.5  $21,427,700,000,000
# 2625                2.9  $19,910,000,000,000
#
#       gross_tertiary_education_enrollment  \
# 1320                                 28.1
# 1688                                 28.1
# 355                                  88.2
# 228                                  60.0
# 1674                                 75.9
# 553                                  88.2
# 2164                                 63.2
# 107                                  70.2
# 1239                                 88.2
# 2625                                 50.6
#
#      gross_primary_education_enrollment_country  life_expectancy_country  \
# 1320                                      113.0                     69.4
# 1688                                      113.0                     69.4
# 355                                       101.8                     78.5
# 228                                       101.2                     81.3
# 1674                                       99.3                     80.8
# 553                                       101.8                     78.5
# 2164                                       98.8                     84.2
# 107                                       104.0                     80.9
# 1239                                      101.8                     78.5
# 2625                                      100.2                     77.0
#
#       total_tax_rate_country  latitude_country  longitude_country
# 1320                    49.7         20.593684          78.962880
# 1688                    49.7         20.593684          78.962880
# 355                     36.6         37.090240         -95.712891
# 228                     30.6         55.378051          -3.435973
# 1674                    22.4         35.126413          33.429859
# 553                     36.6         37.090240         -95.712891
# 2164                    46.7         36.204824         138.252924
# 107                     48.8         51.165691          10.451526
# 1239                    36.6         37.090240         -95.712891
# 2625                    59.2         35.861660         104.195397
#
# [10 rows x 22 columns]

# %%
# make the data frame interactive
idf=df.interactive()

# %% [markdown]
# # (0) create a gender distributiion pie chart

# %%
genderPipeline=df['gender'].value_counts().reset_index()
genderPipeline['percentage']=genderPipeline['count']/genderPipeline['count'].sum()*100
genderPie=genderPipeline.hvplot.bar(
    x='gender',
    y="percentage",
    stacked=False,
    height=400,
    width=400,
    polar=True
)
genderPie
# Out:
# WARNING:param.main: polar option not found for bar plot with bokeh; similar options include: ['colorbar', 'color', 'color']
# :Bars   [gender]   (percentage)

# %% [markdown]
# # (1) create male and female RadioButton

# %%
genderSelector=pn.widgets.RadioButtonGroup(
    name="genderSelector",
    options=["M","F"],
    button_type='success'
)
genderSelector
# Out:
# RadioButtonGroup(button_type='success', name='genderSelector', options=['M', 'F'], value='M')

# %% [markdown]
# # (2) create age distribution histogram

# %%
agePipeline=idf.loc[idf["gender"]==genderSelector,"age"]
ageHist=agePipeline.hvplot.hist(bins=20,title="age distribution of billionaries")

ageHist
# Out:
# <div id='47974745-9943-4e39-89d0-6f56a90ee49f'>
#   <div id="b47bfa72-fab0-4c96-a901-c7661a00ed11" data-root-id="47974745-9943-4e39-89d0-6f56a90ee49f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"07fe0242-7631-47af-9de7-6da7c2586be2":{"version":"3.3.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"47974745-9943-4e39-89d0-6f56a90ee49f","attributes":{"name":"Row25017","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"2d5107a7-6c73-4b65-8640-53ad3ba1345f","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"dcfa4e1a-7e18-4a17-87a3-fa1ca954e94a","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"60588945-2bdf-4348-9dd1-de2056572bed","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"abf3e4c3-cae4-493e-8da3-1769f6bb21fe","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Figure","id":"ee39e9b2-a4af-4587-9cf4-7e3f663f1d6d","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"28070dfd-7558-438d-9514-99b765d63df0","attributes":{"tags":[[["age","age",null]],[]],"start":15.442857142857143,"end":105.55714285714286,"reset_start":15.442857142857143,"reset_end":105.55714285714286}},"y_range":{"type":"object","name":"Range1d","id":"a002c712-cee9-478e-a21d-90d81d49a152","attributes":{"tags":[[["age_count","Count",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"end":357.4,"reset_start":0.0,"reset_end":357.4}},"x_scale":{"type":"object","name":"LinearScale","id":"3ad8818b-c9f8-4c09-9383-995cbe9be9b6"},"y_scale":{"type":"object","name":"LinearScale","id":"ee0276ab-6d5b-4356-b121-762e77c439e5"},"title":{"type":"object","name":"Title","id":"d07e89ea-2d24-4e67-91fa-3ec3f09b890d","attributes":{"text":"age distribution of billionaries","text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"b5b053df-a40d-49cd-855e-d6845ef67971","attributes":{"data_source":{"type":"object","name":"ColumnDataSource","id":"6470cf14-fc70-4828-9068-7b1330dfbca2","attributes":{"selected":{"type":"object","name":"Selection","id":"1cb6967b-fb85-4266-a5a6-1a85ba18fbb1","attributes":{"indices":[],"line_indices":[]}},"selection_policy":{"type":"object","name":"UnionRenderers","id":"2289542e-357e-4589-9a91-a981c81729a7"},"data":{"type":"map","entries":[["top",{"type":"ndarray","array":{"type":"bytes","data":"AwAAAAEAAAAIAAAACQAAABsAAAA5AAAAXQAAAIcAAADNAAAARQEAAOgAAAAAAQAA3gAAABABAACsAAAAgAAAAFUAAAAoAAAAGQAAAAgAAAA="},"shape":[20],"dtype":"int32","order":"little"}],["left",{"type":"ndarray","array":{"type":"bytes","data":"AAAAAAAAM0BmZmZmZiY3QM3MzMzMTDtANDMzMzNzP0DNzMzMzMxBQAAAAAAA4ENANDMzMzPzRUBnZmZmZgZIQJqZmZmZGUpAzczMzMwsTEAAAAAAAEBOQJqZmZmZKVBANDMzMzMzUUDNzMzMzDxSQGdmZmZmRlNAAAAAAABQVECamZmZmVlVQDQzMzMzY1ZAzczMzMxsV0BnZmZmZnZYQA=="},"shape":[20],"dtype":"float64","order":"little"}],["right",{"type":"ndarray","array":{"type":"bytes","data":"ZmZmZmYmN0DNzMzMzEw7QDQzMzMzcz9AzczMzMzMQUAAAAAAAOBDQDQzMzMz80VAZ2ZmZmYGSECamZmZmRlKQM3MzMzMLExAAAAAAABATkCamZmZmSlQQDQzMzMzM1FAzczMzMw8UkBnZmZmZkZTQAAAAAAAUFRAmpmZmZlZVUA0MzMzM2NWQM3MzMzMbFdAZ2ZmZmZ2WEAAAAAAAIBZQA=="},"shape":[20],"dtype":"float64","order":"little"}],["age",{"type":"ndarray","array":{"type":"bytes","data":"MzMzMzMTNUCamZmZmTk5QAAAAAAAYD1ANDMzMzPDQEBmZmZmZtZCQJqZmZmZ6URAzszMzMz8RkAAAAAAABBJQDQzMzMzI0tAZmZmZmY2TUCamZmZmUlPQGdmZmZmrlBAAAAAAAC4UUCamZmZmcFSQDQzMzMzy1NAzczMzMzUVEBnZmZmZt5VQAAAAAAA6FZAmpmZmZnxV0A0MzMzM/tYQA=="},"shape":[20],"dtype":"float64","order":"little"}],["age_count",{"type":"ndarray","array":{"type":"bytes","data":"AwAAAAEAAAAIAAAACQAAABsAAAA5A ...

# %% [markdown]
# # (3) create a side bar chart of top 10 countries with most billionaries

# %%
countriesPipeline=idf.loc[idf["gender"]==genderSelector,"country"].value_counts().head(10)
countriesBarH=countriesPipeline.hvplot.barh(title="top 10 countries with most billionarires")
countriesBarH
# Out:
# <div id='f604b2d2-30ea-4236-b023-810e71d5b453'>
#   <div id="f900a496-6c23-4bb8-be01-4439dc71311e" data-root-id="f604b2d2-30ea-4236-b023-810e71d5b453" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"38ed4ae0-19df-4ebd-b06c-d288c7a122f3":{"version":"3.3.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"f604b2d2-30ea-4236-b023-810e71d5b453","attributes":{"name":"Row01950","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"0b0f7267-360d-45fe-ae63-6d957b55c7fd","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"b83b0768-355c-45dc-bcc4-391aa1fad686","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"fc4d872d-e309-4c9c-8ef7-4d481dc124a7","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"85c32275-b1ea-4b57-a15e-eb6bc7d0c236","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Figure","id":"f7564356-1185-41e4-a609-06ad395e2d65","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"e8558e72-b48c-446c-ba44-e67462d191b9","attributes":{"tags":[[["count","count",null]],[]],"end":717.3,"reset_start":0.0,"reset_end":717.3}},"y_range":{"type":"object","name":"FactorRange","id":"42035982-8030-4ffc-816b-e8d37332738e","attributes":{"tags":[[["country","country",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"factors":["United States","China","India","Germany","Russia","United Kingdom","Switzerland","Hong Kong","Singapore","Taiwan"]}},"x_scale":{"type":"object","name":"LinearScale","id":"51d19d2f-4c3b-4c27-a397-6666087a5516"},"y_scale":{"type":"object","name":"CategoricalScale","id":"9c0ff8e0-7d45-4004-8ab6-27a7c82775db"},"title":{"type":"object","name":"Title","id":"0a746106-8930-446c-9431-effee68b1d8b","attributes":{"text":"top 10 countries with most billionarires","text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"58d40fc7-fc9e-4f14-b93d-dc329bb78182","attributes":{"data_source":{"type":"object","name":"ColumnDataSource","id":"e27096ac-bd34-4b0d-b85a-8bbe6ae1f63c","attributes":{"selected":{"type":"object","name":"Selection","id":"616aaa4d-d55b-453f-b079-66c03db9bd82","attributes":{"indices":[],"line_indices":[]}},"selection_policy":{"type":"object","name":"UnionRenderers","id":"0db58243-35ec-4dfa-a834-019147b80ad2"},"data":{"type":"map","entries":[["country",["United States","China","India","Germany","Russia","United Kingdom","Switzerland","Hong Kong","Singapore","Taiwan"]],["count",{"type":"ndarray","array":{"type":"bytes","data":"kAIAANUBAACTAAAAUQAAAE4AAABLAAAAQgAAADgAAAAtAAAAKwAAAA=="},"shape":[10],"dtype":"int32","order":"little"}]]}}},"view":{"type":"object","name":"CDSView","id":"4efded1c-d194-404d-b490-fb16191f1f48","attributes":{"filter":{"type":"object","name":"AllIndices","id":"a009fba3-c0c2-4da7-ae7e-1b83d80731f0"}}},"glyph":{"type":"object","name":"HBar","id":"64dd9a58-ae2a-449c-9431-6936270a1ff4","attributes":{"tags":["apply_ranges"],"y":{"type":"field","field":"country"},"height":{"type":"value","value":0.8},"right":{"type":"field","field":"count"},"fill_color":{"type":"value","value":"#30a2da"},"hatch_color":{"type":"value","value":"#30a2da"}}},"selection_glyph":{"type":"object","name":"HBar","id":"7b804a7a-83c8-4dd0-86b6-e29b411cc671","attributes":{"tags":["apply_ranges"],"y":{"type":"field","field":"country"},"height":{"type":"value","value":0.8},"left":{"type":"value","value":0},"right":{"type":"field","field":"count"},"line_color":{"type":"value","value":"black"},"line_alpha":{"type":"value","value":1.0},"line_width":{"type":"value","value":1},"line_join":{"typ ...

# %% [markdown]
# # (4) create a treemap of industries of billionaires

# %%
industriesPipeline=df["industries"].value_counts().reset_index()
fig = px.treemap(industriesPipeline,path=["industries"],values="count",
                           title="billionarires industries distribution")
fig.update_traces(textinfo="label+percent entry")
fig.update_layout(margin=dict(t=50,l=0,r=0,b=0))

industriesTree=pn.pane.Plotly(fig)
industriesTree
# Out:
# Plotly(Figure)

# %% [markdown]
# # (5) Crete a tree map showing the percentage of billionaries money from each industires

# %%
industiesMoneyPipeline=df.groupby("industries")["finalWorth"].sum().sort_values(ascending=False).reset_index()
fig = px.treemap(industiesMoneyPipeline,path=["industries"],values="finalWorth",
                           title="billionarires finalWorth from each industries")
fig.update_traces(textinfo="label+percent entry")
fig.update_layout(margin=dict(t=50,l=0,r=0,b=0))

industriesMoneyTree=pn.pane.Plotly(fig)
industriesMoneyTree
# Out:
# Plotly(Figure)

# %% [markdown]
# # (6) create Selfmade or inheried Percentage piechart

# %%
selfmadePipeline=df["selfMade"].value_counts().reset_index()
selfmadePie=px.pie(selfmadePipeline,values="count",names=["selfMade","inherited"],title="SelfMade Billionaries VS inherited Billionaires")
selfmadePie.update_layout(legend=dict(orientation="h"))

selfmadePie=pn.pane.Plotly(selfmadePie)
selfmadePie
# Out:
# Plotly(Figure)
